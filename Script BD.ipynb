-- %% [markdown]
-- # [dbo].[Permisos]

-- %%
USE [PortalWeb]
GO

-- %%
/****** Object:  Table [dbo].[Permisos]    Script Date: 2/03/2024 10:44:33 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Permisos](
	[Id_Permiso] [int] IDENTITY(1,1) NOT NULL,
	[Nombre_Permiso] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 2/03/2024 10:44:33 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id_Rol] [int] IDENTITY(1,1) NOT NULL,
	[Nombre_Rol] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles_Permisos]

-- %%
/****** Object:  Table [dbo].[Roles_Permisos]    Script Date: 2/03/2024 10:44:33 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles_Permisos](
	[Id_rol_permiso] [int] IDENTITY(1,1) NOT NULL,
	[Id_Rol] [int] NULL,
	[Id_Permiso] [int] NULL,
	[Estado] [bit] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 2/03/2024 10:44:33 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[Id_usuarios] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](50) NULL,
	[Edad] [int] NULL,
	[Usuario] [varchar](50) NULL,
	[Clave] [varchar](50) NULL,
	[Id_rol] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Permisos]

-- %%
SET IDENTITY_INSERT [dbo].[Permisos] ON 
INSERT [dbo].[Permisos] ([Id_Permiso], [Nombre_Permiso]) VALUES (1, N'Create')
INSERT [dbo].[Permisos] ([Id_Permiso], [Nombre_Permiso]) VALUES (2, N'Read')
INSERT [dbo].[Permisos] ([Id_Permiso], [Nombre_Permiso]) VALUES (3, N'Update')
INSERT [dbo].[Permisos] ([Id_Permiso], [Nombre_Permiso]) VALUES (4, N'Delete')
SET IDENTITY_INSERT [dbo].[Permisos] OFF
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
SET IDENTITY_INSERT [dbo].[Roles] ON 
INSERT [dbo].[Roles] ([Id_Rol], [Nombre_Rol]) VALUES (1, N'Amind')
INSERT [dbo].[Roles] ([Id_Rol], [Nombre_Rol]) VALUES (2, N'User')
SET IDENTITY_INSERT [dbo].[Roles] OFF
GO

-- %% [markdown]
-- # [dbo].[Roles_Permisos]

-- %%
SET IDENTITY_INSERT [dbo].[Roles_Permisos] ON 
INSERT [dbo].[Roles_Permisos] ([Id_rol_permiso], [Id_Rol], [Id_Permiso], [Estado]) VALUES (1, 1, 1, 1)
INSERT [dbo].[Roles_Permisos] ([Id_rol_permiso], [Id_Rol], [Id_Permiso], [Estado]) VALUES (2, 1, 2, 1)
INSERT [dbo].[Roles_Permisos] ([Id_rol_permiso], [Id_Rol], [Id_Permiso], [Estado]) VALUES (3, 1, 3, 1)
INSERT [dbo].[Roles_Permisos] ([Id_rol_permiso], [Id_Rol], [Id_Permiso], [Estado]) VALUES (4, 1, 4, 1)
INSERT [dbo].[Roles_Permisos] ([Id_rol_permiso], [Id_Rol], [Id_Permiso], [Estado]) VALUES (5, 2, 1, 0)
INSERT [dbo].[Roles_Permisos] ([Id_rol_permiso], [Id_Rol], [Id_Permiso], [Estado]) VALUES (6, 2, 2, 1)
INSERT [dbo].[Roles_Permisos] ([Id_rol_permiso], [Id_Rol], [Id_Permiso], [Estado]) VALUES (7, 2, 3, 0)
INSERT [dbo].[Roles_Permisos] ([Id_rol_permiso], [Id_Rol], [Id_Permiso], [Estado]) VALUES (8, 2, 4, 0)
SET IDENTITY_INSERT [dbo].[Roles_Permisos] OFF
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
SET IDENTITY_INSERT [dbo].[Usuarios] ON 
INSERT [dbo].[Usuarios] ([Id_usuarios], [Nombre], [Edad], [Usuario], [Clave], [Id_rol]) VALUES (1, N'juan', 24, N'jf', N'ZwïìÍ[ñ
6•#1;s“¥\·Bá•h¦MCŽ_', 2)
INSERT [dbo].[Usuarios] ([Id_usuarios], [Nombre], [Edad], [Usuario], [Clave], [Id_rol]) VALUES (2, N'jose', 30, N'jose2', N'ƒ‚­žâé¼3ÍøM¤d^ú‚ù—›­ˆÌ¬™„¢', 1)
SET IDENTITY_INSERT [dbo].[Usuarios] OFF
GO

-- %% [markdown]
-- # [dbo].[sp_datos]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_datos]    Script Date: 2/03/2024 10:44:33 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[sp_datos]
as begin
select * from Usuarios
end
GO

-- %% [markdown]
-- # [dbo].[sp_Login]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Login]    Script Date: 2/03/2024 10:44:33 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[sp_Login]

@Usuario varchar(50),
@Clave varchar(max),
@Patron varchar(50)
as begin

select * from Usuarios where Usuario=@Usuario and convert(varchar(50), DECRYPTBYPASSPHRASE(@Patron, Clave)) = @Clave
end
GO

-- %% [markdown]
-- # [dbo].[sp_Permisos]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Permisos]    Script Date: 2/03/2024 10:44:33 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[sp_Permisos]

@Id_Rol int
as begin

select Nombre_Permiso, Estado from Roles_Permisos inner join Permisos on Permisos.Id_Permiso = Roles_Permisos.Id_Permiso where Id_Rol = @Id_Rol
end
GO

-- %% [markdown]
-- # [dbo].[sp_registrar]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_registrar]    Script Date: 2/03/2024 10:44:33 a. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[sp_registrar]
@Nombre varchar(50),
@Edad int,
@Usuario varchar(50),
@Clave varchar(max),
@Id_Rol int = 2,
@Patron varchar(50)

as begin

insert into Usuarios values (@Nombre, @Edad, @Usuario, ENCRYPTBYPASSPHRASE(@Patron, @Clave), @Id_Rol)

end
GO
